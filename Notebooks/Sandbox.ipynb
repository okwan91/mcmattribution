# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import seaborn as sns
from collections import defaultdict

# %%
data = pd.read_csv('data/data.csv').drop('Unnamed: 0', axis = 1)

# %%
data['revenue'] = np.where(data['purchase'] == False, 0, 15)
data.replace({True: 1, False: 0}, inplace = True)
data.head()
# Out:
#        uid            timestamp   channel  clickthrough  purchase  gender  \
# 0  2697588  2021-01-01 08:00:00  facebook             0         0  Female
# 1  2697588  2021-01-02 08:00:00     email             0         0  Female
# 2  2697588  2021-01-02 09:20:00    search             0         0  Female
# 3  2697588  2021-01-02 10:40:00    search             0         1  Female
# 4  2697588  2021-01-02 12:00:00  facebook             0         0  Female
#
#          age  revenue
# 0  Gen Alpha        0
# 1  Gen Alpha        0
# 2  Gen Alpha        0
# 3  Gen Alpha       15
# 4  Gen Alpha        0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6822361 entries, 0 to 6822360
# Data columns (total 7 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   uid           int64
#  1   timestamp     object
#  2   channel       object
#  3   clickthrough  bool
#  4   purchase      bool
#  5   gender        object
#  6   age           object
# dtypes: bool(2), int64(1), object(4)
# memory usage: 273.3+ MB

# %%
heat = sns.heatmap(data[['channel', 'clickthrough','purchase']]).corr()
heat

# %%
sns.countplot(x = 'channel', data = data)
plt.show()

# %%
channels = data.groupby('channel')['purchase'].sum()
channels.plot.bar()
plt.title('Total Purchases by Channel')
plt.ylabel('Purchases')
# Out:
# Text(0, 0.5, 'Purchases')

# %%
visits = data.groupby('channel')['timestamp'].count()
visits.plot.bar()
plt.title('Total Visits Per Channel')
# Out:
# Text(0.5, 1.0, 'Total Visits Per Channel')

# %%
gender = data.groupby(['gender', 'channel'])['purchase'].sum()
gender.plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='gender,channel'>

# %%
data.groupby(['gender', 'age', 'channel'])['revenue'].sum()
# Out:
# gender  age        channel
# Female  Boomer     email        4170
#                    facebook     3780
#                    search       3600
#                    youtube      1365
#         Gen Alpha  email       32385
#                    facebook    25500
#                    search      24510
#                    youtube      8625
#         Gen Z      email        3870
#                    facebook     2970
#                    search       3585
#                    youtube      1215
#         Millenial  email        4080
#                    facebook     3420
#                    search       3330
#                    youtube      1275
# Male    Boomer     email        4305
#                    facebook     3075
#                    search       3510
#                    youtube      1155
#         Gen Alpha  email       31725
#                    facebook    24255
#                    search      22740
#                    youtube      8520
#         Gen Z      email        4425
#                    facebook     3015
#                    search       3555
#                    youtube      1305
#         Millenial  email        4770
#                    facebook     3915
#                    search       3585
#                    youtube      1290
# Name: revenue, dtype: int64

# %%
conversions = data.groupby('channel')['purchase'].sum()
conversions
# Out:
# channel
# email       5982
# facebook    4662
# search      4561
# youtube     1650
# Name: purchase, dtype: int64

# %%
clickthrough = data.groupby(['gender', 'channel'])['clickthrough'].sum()

clickthrough.plot.bar()
# Out:
# <AxesSubplot:xlabel='gender,channel'>

# %%
data[(data['uid'] == 2697588) & (data['purchase'] == 1)]
# Out:
#          uid            timestamp channel  clickthrough  purchase  gender  \
# 3    2697588  2021-01-02 10:40:00  search             0         1  Female
# 366  2697588  2021-03-21 17:50:46  search             0         1  Female
#
#            age  revenue
# 3    Gen Alpha       15
# 366  Gen Alpha       15

# %%
pur = data[data['purchase']==1].groupby('channel')['timestamp'].mean()

pur
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-39-628760369b11> in <module>
# ----> 1 pur = data[data['purchase']==1].groupby('channel')['timestamp'].mean()
#       2
#       3 pur
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1079
#    1080         if not output:
# -> 1081             raise DataError("No numeric types to aggregate")
#    1082
#    1083         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %%
ax = sns.barplot(x = data['gender'], y = data['clickthrough'], hue = data['channel'])
ax.set_title('Channel Clickthrough by Gender')
# Out:
# Text(0.5, 1.0, 'Channel Clickthrough by Gender')

# %%
ax = sns.barplot(x = data['gender'], y = data['purchase'], hue = data['channel'])
ax.set_title('Channel Purchase by Gender')
# Out:
# Text(0.5, 1.0, 'Channel Purchase by Gender')

# %%
test = data[data['uid'] == 1000276]
test
# Out:
#              uid            timestamp   channel  clickthrough  purchase  \
# 5384911  1000276  2021-01-01 08:00:00  facebook             0         0
# 5384912  1000276  2021-01-01 08:32:00  facebook             0         0
# 5384913  1000276  2021-01-01 09:04:00  facebook             0         0
# 5384914  1000276  2021-01-01 09:36:00  facebook             0         0
# 5384915  1000276  2021-01-01 10:08:00    search             0         0
# ...          ...                  ...       ...           ...       ...
# 5385892  1000276  2021-04-10 20:00:00  facebook             0         0
# 5385893  1000276  2021-04-10 20:40:00  facebook             0         0
# 5385894  1000276  2021-04-10 21:20:00  facebook             0         0
# 5385895  1000276  2021-04-10 22:00:00     email             0         0
# 5385896  1000276  2021-04-10 22:40:00  facebook             0         0
#
#         gender        age  revenue
# 5384911   Male  Gen Alpha        0
# 5384912   Male  Gen Alpha        0
# 5384913   Male  Gen Alpha        0
# 5384914   Male  Gen Alpha        0
# 5384915   Male  Gen Alpha        0
# ...        ...        ...      ...
# 5385892   Male  Gen Alpha        0
# 5385893   Male  Gen Alpha        0
# 5385894   Male  Gen Alpha        0
# 5385895   Male  Gen Alpha        0
# 5385896   Male  Gen Alpha        0
#
# [986 rows x 8 columns]

# %%
#trying to note down the marketing path until a conversion
def marketing_path(uid, data): 
    user = data[data['uid'] == uid] 
    path = []
    for channel, buy in zip(user['channel'], user['purchase']):
        if buy == 0 and channel not in path:
            path.append(channel)
        elif buy == 1:
            path.append(channel)
            break
    return path
            
marketing_path(2697588, data)
# Out:
# ['facebook', 'email', 'search', 'search']

# %%
path = pd.DataFrame(data['uid'].unique(), columns = ['uid'])
path['channel'] = path['uid'].apply(lambda row: marketing_path(row,data))

# %%
path
# Out:
#           uid                                      channel
# 0     2697588            [facebook, email, search, search]
# 1     9569845           [email, facebook, youtube, search]
# 2     4983829    [search, facebook, email, youtube, email]
# 3     4183239   [facebook, email, search, youtube, search]
# 4     4984417  [youtube, facebook, search, email, youtube]
# ...       ...                                          ...
# 9988  5466211          [facebook, search, youtube, search]
# 9989  9024244           [facebook, email, search, youtube]
# 9990  9018528           [facebook, youtube, search, email]
# 9991  2277899   [email, facebook, youtube, search, search]
# 9992  1530995    [facebook, youtube, search, email, email]
#
# [9993 rows x 2 columns]

# %%
#am easier way to follow the marketing path of a customer
# path = data.groupby('uid')['channel'].aggregate(lambda x: x.unique().tolist()).reset_index()

# %%
#removing duplicated UID's and keeping purchase data
last = data.drop_duplicates('uid', keep = 'last')[['uid','purchase','gender','age']]
last
# Out:
#              uid  purchase  gender        age
# 481      2697588         0  Female  Gen Alpha
# 1006     9569845         0  Female  Gen Alpha
# 1343     4983829         0  Female  Gen Alpha
# 2223     4183239         0    Male  Gen Alpha
# 3073     4984417         0    Male      Gen Z
# ...          ...       ...     ...        ...
# 6819758  5466211         0  Female  Gen Alpha
# 6819982  9024244         0    Male  Gen Alpha
# 6820860  9018528         0  Female  Gen Alpha
# 6821661  2277899         0  Female  Gen Alpha
# 6822360  1530995         0  Female  Gen Alpha
#
# [9993 rows x 4 columns]

# %%
path = pd.merge(path, last, how = "left", on = 'uid')
path
# Out:
#           uid                                      channel  purchase  gender  \
# 0     2697588            [facebook, email, search, search]         0  Female
# 1     9569845           [email, facebook, youtube, search]         0  Female
# 2     4983829    [search, facebook, email, youtube, email]         0  Female
# 3     4183239   [facebook, email, search, youtube, search]         0    Male
# 4     4984417  [youtube, facebook, search, email, youtube]         0    Male
# ...       ...                                          ...       ...     ...
# 9988  5466211          [facebook, search, youtube, search]         0  Female
# 9989  9024244           [facebook, email, search, youtube]         0    Male
# 9990  9018528           [facebook, youtube, search, email]         0  Female
# 9991  2277899   [email, facebook, youtube, search, search]         0  Female
# 9992  1530995    [facebook, youtube, search, email, email]         0  Female
#
#             age
# 0     Gen Alpha
# 1     Gen Alpha
# 2     Gen Alpha
# 3     Gen Alpha
# 4         Gen Z
# ...         ...
# 9988  Gen Alpha
# 9989  Gen Alpha
# 9990  Gen Alpha
# 9991  Gen Alpha
# 9992  Gen Alpha
#
# [9993 rows x 5 columns]

# %%
path[path['purchase'] == 1].count()
# Out:
# uid         37
# channel     37
# purchase    37
# dtype: int64

# %%
con = []
for row in path['purchase']:
    if row == 1:
        con.append(['conversion'])
    else:
        con.append(['end'])
        
con.count(['conversion'])
# Out:
# 37

# %%
path['conversion'] = con
path['channel'] = path['channel'] + path['conversion']
path
# Out:
#           uid                                           channel  purchase  \
# 0     2697588            [facebook, email, search, search, end]         0
# 1     9569845           [email, facebook, youtube, search, end]         0
# 2     4983829    [search, facebook, email, youtube, email, end]         0
# 3     4183239   [facebook, email, search, youtube, search, end]         0
# 4     4984417  [youtube, facebook, search, email, youtube, end]         0
# ...       ...                                               ...       ...
# 9988  5466211          [facebook, search, youtube, search, end]         0
# 9989  9024244           [facebook, email, search, youtube, end]         0
# 9990  9018528           [facebook, youtube, search, email, end]         0
# 9991  2277899   [email, facebook, youtube, search, search, end]         0
# 9992  1530995    [facebook, youtube, search, email, email, end]         0
#
#       gender        age conversion
# 0     Female  Gen Alpha      [end]
# 1     Female  Gen Alpha      [end]
# 2     Female  Gen Alpha      [end]
# 3       Male  Gen Alpha      [end]
# 4       Male      Gen Z      [end]
# ...      ...        ...        ...
# 9988  Female  Gen Alpha      [end]
# 9989    Male  Gen Alpha      [end]
# 9990  Female  Gen Alpha      [end]
# 9991  Female  Gen Alpha      [end]
# 9992  Female  Gen Alpha      [end]
#
# [9993 rows x 6 columns]

# %%
path['test'] = path['channel'].map(lambda x: x.insert(0,'start'))

path
# Out:
#           uid                                            channel  purchase  \
# 0     2697588      [start, facebook, email, search, search, end]         0
# 1     9569845     [start, email, facebook, youtube, search, end]         0
# 2     4983829  [start, search, facebook, email, youtube, emai...         0
# 3     4183239  [start, facebook, email, search, youtube, sear...         0
# 4     4984417  [start, youtube, facebook, search, email, yout...         0
# ...       ...                                                ...       ...
# 9988  5466211    [start, facebook, search, youtube, search, end]         0
# 9989  9024244     [start, facebook, email, search, youtube, end]         0
# 9990  9018528     [start, facebook, youtube, search, email, end]         0
# 9991  2277899  [start, email, facebook, youtube, search, sear...         0
# 9992  1530995  [start, facebook, youtube, search, email, emai...         0
#
#       gender        age conversion  test
# 0     Female  Gen Alpha      [end]  None
# 1     Female  Gen Alpha      [end]  None
# 2     Female  Gen Alpha      [end]  None
# 3       Male  Gen Alpha      [end]  None
# 4       Male      Gen Z      [end]  None
# ...      ...        ...        ...   ...
# 9988  Female  Gen Alpha      [end]  None
# 9989    Male  Gen Alpha      [end]  None
# 9990  Female  Gen Alpha      [end]  None
# 9991  Female  Gen Alpha      [end]  None
# 9992  Female  Gen Alpha      [end]  None
#
# [9993 rows x 7 columns]

# %%
path = path[['uid','channel','gender','age']]
#1105013
path
# Out:
#           uid                                            channel  gender  \
# 0     2697588      [start, facebook, email, search, search, end]  Female
# 1     9569845     [start, email, facebook, youtube, search, end]  Female
# 2     4983829  [start, search, facebook, email, youtube, emai...  Female
# 3     4183239  [start, facebook, email, search, youtube, sear...    Male
# 4     4984417  [start, youtube, facebook, search, email, yout...    Male
# ...       ...                                                ...     ...
# 9988  5466211    [start, facebook, search, youtube, search, end]  Female
# 9989  9024244     [start, facebook, email, search, youtube, end]    Male
# 9990  9018528     [start, facebook, youtube, search, email, end]  Female
# 9991  2277899  [start, email, facebook, youtube, search, sear...  Female
# 9992  1530995  [start, facebook, youtube, search, email, emai...  Female
#
#             age
# 0     Gen Alpha
# 1     Gen Alpha
# 2     Gen Alpha
# 3     Gen Alpha
# 4         Gen Z
# ...         ...
# 9988  Gen Alpha
# 9989  Gen Alpha
# 9990  Gen Alpha
# 9991  Gen Alpha
# 9992  Gen Alpha
#
# [9993 rows x 4 columns]

# %%
num_of_paths = path['channel']
conversiontotal = sum(path.count('conversion') for path in num_of_paths.tolist())
def base_rate(df):
    total_conversion = sum(path.count('conversion') for path in df.tolist())
    base_rate = total_conversion/len(num_of_paths)
    return base_rate
    
baserate = base_rate(num_of_paths)
baserate
# Out:
# 0.003702591814269989

# %%
#counting how many times users went from one channel/state to another

def transition_states(list_of_paths):
    list_of_unique_channels = set(x for element in list_of_paths for x in element)
    transition_states = {x + '>' + y: 0 for x in list_of_unique_channels for y in list_of_unique_channels}

    for possible_state in list_of_unique_channels:
        if possible_state not in ['conversion', 'end']:
            for user_path in list_of_paths:
                if possible_state in user_path:
                    indices = [i for i, s in enumerate(user_path) if possible_state in s]
                    for col in indices:
                        transition_states[user_path[col] + '>' + user_path[col + 1]] += 1

    return transition_states


trans_states = transition_states(num_of_paths)
trans_states
# Out:
# {'facebook>facebook': 250,
#  'facebook>conversion': 9,
#  'facebook>search': 2977,
#  'facebook>end': 2637,
#  'facebook>youtube': 2601,
#  'facebook>start': 0,
#  'facebook>email': 2958,
#  'conversion>facebook': 0,
#  'conversion>conversion': 0,
#  'conversion>search': 0,
#  'conversion>end': 0,
#  'conversion>youtube': 0,
#  'conversion>start': 0,
#  'conversion>email': 0,
#  'search>facebook': 2883,
#  'search>conversion': 8,
#  'search>search': 228,
#  'search>end': 2659,
#  'search>youtube': 2620,
#  'search>start': 0,
#  'search>email': 3063,
#  'end>facebook': 0,
#  'end>conversion': 0,
#  'end>search': 0,
#  'end>end': 0,
#  'end>youtube': 0,
#  'end>start': 0,
#  'end>email': 0,
#  'youtube>facebook': 2854,
#  'youtube>conversion': 3,
#  'youtube>search': 2837,
#  'youtube>end': 1494,
#  'youtube>youtube': 71,
#  'youtube>start': 0,
#  'youtube>email': 3096,
#  'start>facebook': 2478,
#  'start>conversion': 0,
#  'start>search': 2563,
#  'start>end': 0,
#  'start>youtube': 2524,
#  'start>start': 0,
#  'start>email': 2428,
#  'email>facebook': 2967,
#  'email>conversion': 17,
#  'email>search': 2856,
#  'email>end': 3166,
#  'email>youtube': 2539,
#  'email>start': 0,
#  'email>email': 402}

# %%
#calculating the transition probability

def transition_prob(trans_dict):
    list_of_unique_channels = set(x for element in num_of_paths for x in element)
    trans_prob = defaultdict(dict)
    for state in list_of_unique_channels:
        if state not in ['conversion', 'end']:
            counter = 0
            index = [i for i, s in enumerate(trans_dict) if state + '>' in s]
            for col in index:
                if trans_dict[list(trans_dict)[col]] > 0:
                    counter += trans_dict[list(trans_dict)[col]]
            for col in index:
                if trans_dict[list(trans_dict)[col]] > 0:
                    state_prob = float((trans_dict[list(trans_dict)[col]])) / float(counter)
                    trans_prob[list(trans_dict)[col]] = state_prob

    return trans_prob


trans_prob = transition_prob(trans_states)
trans_prob
# Out:
# defaultdict(dict,
#             {'facebook>facebook': 0.021868439468159553,
#              'facebook>conversion': 0.0007872638208537439,
#              'facebook>search': 0.2604093771868439,
#              'facebook>end': 0.23066829951014695,
#              'facebook>youtube': 0.22751924422673198,
#              'facebook>email': 0.2587473757872638,
#              'search>facebook': 0.2515487304772707,
#              'search>conversion': 0.0006980193700375186,
#              'search>search': 0.01989355204606928,
#              'search>end': 0.23200418811622023,
#              'search>youtube': 0.22860134368728732,
#              'search>email': 0.26725416630311494,
#              'youtube>facebook': 0.2756156446161275,
#              'youtube>conversion': 0.0002897151134717528,
#              'youtube>search': 0.27397392563978756,
#              'youtube>end': 0.14427812650893287,
#              'youtube>youtube': 0.006856591018831483,
#              'youtube>email': 0.29898599710284884,
#              'start>facebook': 0.24797358150705495,
#              'start>search': 0.2564795356749725,
#              'start>youtube': 0.25257680376263386,
#              'start>email': 0.24297007905533874,
#              'email>facebook': 0.2483468653218381,
#              'email>conversion': 0.0014229513685444044,
#              'email>search': 0.23905582991545996,
#              'email>end': 0.2650037666359756,
#              'email>youtube': 0.21252197204319076,
#              'email>email': 0.03364861471499121})

# %%
#creating a matrix to easily view the probabilities between different stages. 

def transition_matrix(num_of_paths, transition_probabilities):
    trans_matrix = pd.DataFrame()
    list_of_unique_channels = set(x for element in num_of_paths for x in element)

    for channel in list_of_unique_channels:
        trans_matrix[channel] = 0.00
        trans_matrix.loc[channel] = 0.00
        trans_matrix.loc[channel][channel] = 1.0 if channel in ['conversion', 'end'] else 0.0

    for key, value in transition_probabilities.items():
        origin, destination = key.split('>')
        trans_matrix.at[origin, destination] = value

    return trans_matrix


trans_matrix = transition_matrix(num_of_paths, trans_prob)
trans_matrix
# Out:
#             facebook  conversion    search       end   youtube  start  \
# facebook    0.021868    0.000787  0.260409  0.230668  0.227519    0.0
# conversion  0.000000    1.000000  0.000000  0.000000  0.000000    0.0
# search      0.251549    0.000698  0.019894  0.232004  0.228601    0.0
# end         0.000000    0.000000  0.000000  1.000000  0.000000    0.0
# youtube     0.275616    0.000290  0.273974  0.144278  0.006857    0.0
# start       0.247974    0.000000  0.256480  0.000000  0.252577    0.0
# email       0.248347    0.001423  0.239056  0.265004  0.212522    0.0
#
#                email
# facebook    0.258747
# conversion  0.000000
# search      0.267254
# end         0.000000
# youtube     0.298986
# start       0.242970
# email       0.033649

# %%
def channel_heatmap(trans_matrix):
    fig, ax = plt.subplots(figsize = (11,8))
    ax = sns.heatmap(trans_matrix, annot = True, cmap="flare", linewidths= 1, linecolor = 'white')
    
channel_heatmap(trans_matrix)

# %%
def gender_heatmap(df, gender):
    focus = df[df['gender'] == gender]
    path = focus[['uid','channel']]
    num_paths = path['channel']
    base_r = base_rate(num_paths)
    trans_states = transition_states(num_paths)
    trans_prob = transition_prob(trans_states)
    t_matrix = transition_matrix(num_paths, trans_prob)
    return channel_heatmap(t_matrix)

# %%
gender_heatmap(path, 'Male')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-f42d1d31fd6e> in <module>
# ----> 1 gender_heatmap(path, 'Male')
#
# NameError: name 'gender_heatmap' is not defined

# %%
gender_heatmap(path, 'Female')

# %%
def age_heatmap(df, age):
    focus = df[df['age'] == age]
    path = focus[['uid','channel']]
    num_paths = path['channel']
    base_r = base_rate(num_paths)
    trans_states = transition_states(num_paths)
    trans_prob = transition_prob(trans_states)
    t_matrix = transition_matrix(num_paths, trans_prob)
    return channel_heatmap(t_matrix)

# %%
age_heatmap(path, 'Boomer')

# %%
age_heatmap(path, 'Gen Z')

# %%
age_heatmap(path, 'Millenial')

# %%
age_heatmap(path, 'Gen Alpha')

# %%
#assessing how much removing each channel will impact our conversion rate.

def removal_effects(df, conversion_rate):
    removal_effects_dict = {}
    channels = [channel for channel in df.columns if channel not in ['start',
                                                                     'end',
                                                                     'conversion']]
    for channel in channels:
        removal_df = df.drop(channel, axis=1).drop(channel, axis=0)
        for column in removal_df.columns:
            row_sum = np.sum(list(removal_df.loc[column]))
            null_pct = float(1) - row_sum
            if null_pct != 0:
                removal_df.loc[column]['end'] = null_pct
            removal_df.loc['end']['end'] = 1.0

        removal_to_conv = removal_df[
            ['end', 'conversion']].drop(['end', 'conversion'], axis=0)
        removal_to_non_conv = removal_df.drop(
            ['end', 'conversion'], axis=1).drop(['end', 'conversion'], axis=0)

        removal_inv_diff = np.linalg.inv(
            np.identity(
                len(removal_to_non_conv.columns)) - np.asarray(removal_to_non_conv))
        removal_dot_prod = np.dot(removal_inv_diff, np.asarray(removal_to_conv))
        removal_cvr = pd.DataFrame(removal_dot_prod,
                                   index=removal_to_conv.index)[[1]].loc['start'].values[0]
        removal_effect = 1 - removal_cvr / conversion_rate
        removal_effects_dict[channel] = removal_effect

    return removal_effects_dict


removal_effects_dict = removal_effects(trans_matrix, baserate)
removal_effects_dict
# Out:
# {'facebook': 0.6478716770589814,
#  'search': 0.6386498051638511,
#  'youtube': 0.579405150016908,
#  'email': 0.7443736531551921}

# %%
plt.figure(figsize=(8,7))
plt.plot(removal_effects_dict.keys(),removal_effects_dict.values())
plt.title('Channel Removal Impacts', size = 20)
plt.xlabel('Channel', size = 15)
plt.ylabel('Percentage', size = 15)
# plt.savefig('channelremoval.png')

# %%
def chain_allocations(removal_effects, total_conversions):
    re_sum = np.sum(list(removal_effects.values()))

    return {k: round((v / re_sum) * total_conversions,2) for k, v in removal_effects.items()}


attributions = chain_allocations(removal_effects_dict, conversiontotal)
attributions
# Out:
# {'facebook': 9.18, 'search': 9.05, 'youtube': 8.21, 'email': 10.55}

# %%
np.sum(list(removal_effects_dict.values()))
# Out:
# 2.610300285394932

# %%
# f, ax = plt.subplots(figsize = (7,8))
y = list(attributions.values())
x = list(attributions.keys())

plt.figure(figsize = (8,7))
ax = plt.bar(x = x, height=y, color = ['red', 'orange', 'pink', 'blue'])
for bar in ax:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval + .1, yval, ha = 'left')

plt.xlabel('Channel', size = 15)
plt.ylabel('Attribution', size = 15)
plt.title('Channel Attribution Levels', size = 20)
# plt.savefig('channelattlvls.png')

# %%
#Attribution levels for females

def gender_attribution(df, gender):
    focus = df[df['gender'] == gender]
    path = focus[['uid','channel']]
    num_paths = path['channel']
    total_conversion = sum(path.count('conversion') for path in num_paths.tolist())
    base_r = base_rate(num_paths)
    trans_states = transition_states(num_paths)
    trans_prob = transition_prob(trans_states)
    t_matrix = transition_matrix(num_paths, trans_prob)
    removal = removal_effects(t_matrix, base_r)
    attribution = chain_allocations(removal, total_conversion)
    return attribution

gender_attribution(path, 'Female')
# Out:
# {'facebook': 5.69, 'email': 7.13, 'search': 4.96, 'youtube': 1.22}

# %%
gender_attribution(path, 'Male')
# Out:
# {'facebook': 3.27, 'email': 7.68, 'search': 3.46, 'youtube': 3.59}

# %%
def demographic_attribution(df, age, gender):
    focus = df[(df['age'] == age) & (df['gender'] == gender)]
    path = focus[['uid','channel']]
    num_paths = path['channel']
    total_conversion = sum(path.count('conversion') for path in num_paths.tolist())
    base_r = base_rate(num_paths)
    trans_states = transition_states(num_paths)
    trans_prob = transition_prob(trans_states)
    t_matrix = transition_matrix(num_paths, trans_prob)
    removal = removal_effects(t_matrix, base_r)
    attribution = chain_allocations(removal, total_conversion)
    
    plt.figure(figsize = (8,7))
    x = list(attribution.keys())
    y = list(attribution.values())
    ax = plt.bar(x = x, height=y, color = ['red', 'orange', 'pink', 'blue'])
    for bar in ax:
        yval = bar.get_height()
        plt.text(bar.get_x(), yval + .04, yval, ha = 'left')
    plt.ylabel('Conversions', size = 15)
    plt.xlabel('Channel', size = 15)
    plt.title(f'{gender} {age} Channel Attribution Levels', size = 20)
    return ax, removal

demographic_attribution(path, 'Millenial', 'Female')
# Out:
# (<BarContainer object of 4 artists>,
#  {'facebook': -6.379258675581404,
#   'email': -4.9675029370962145,
#   'search': -3.240279577452662,
#   'youtube': -7.7635660940443785})

# %%
def age_attribution(df, age):
    focus = df[(df['age'] == age)]
    path = focus[['uid','channel']]
    num_paths = path['channel']
    total_conversion = sum(path.count('conversion') for path in num_paths.tolist())
    base_r = base_rate(num_paths)
    trans_states = transition_states(num_paths)
    trans_prob = transition_prob(trans_states)
    t_matrix = transition_matrix(num_paths, trans_prob)
    removal = removal_effects(t_matrix, base_r)
    attribution = chain_allocations(removal, total_conversion)
    
    plt.figure(figsize = (8,7))
    x = list(attribution.keys())
    y = list(attribution.values())
    ax = plt.bar(x = x, height=y, color = ['red', 'orange', 'pink', 'blue'])
    for bar in ax:
        yval = bar.get_height()
        plt.text(bar.get_x(), yval + .04, yval, ha = 'left')
    plt.ylabel('Conversions', size = 15)
    plt.xlabel('Channel', size = 15)
    plt.title(f'{age} Channel Attribution Levels', size = 20)
    return ax, removal

age_attribution(path, 'Gen Alpha')
# Out:
# (<BarContainer object of 4 artists>,
#  {'facebook': 0.5100535594978525,
#   'email': 0.6494419753359193,
#   'search': 0.45577554824398914,
#   'youtube': 0.4056472049197166})

# %%
impressions = data.groupby(['gender','age','uid','channel']).agg({'timestamp':'count',
                                                       'clickthrough': 'sum',
                                                       'purchase': 'sum'})

impressions
# Out:
#                                    timestamp  clickthrough  purchase
# gender age       uid     channel
# Female Boomer    1009283 email            47             3         0
#                          facebook        102             2         0
#                          search          241             2         0
#                          youtube         309             8         0
#                  1040848 email            83             0         2
# ...                                      ...           ...       ...
# Male   Millenial 9952505 youtube         176             3         0
#                  9953503 email            71             2         2
#                          facebook         56             0         0
#                          search          345             2         1
#                          youtube         117             2         0
#
# [39800 rows x 3 columns]

# %%
impressions['CTR'] = impressions['clickthrough']/impressions['timestamp']
impressions['conversion_rate'] = impressions['purchase']/impressions['timestamp']

impressions
# Out:
#                                    timestamp  clickthrough  purchase  \
# gender age       uid     channel
# Female Boomer    1009283 email            47             3         0
#                          facebook        102             2         0
#                          search          241             2         0
#                          youtube         309             8         0
#                  1040848 email            83             0         2
# ...                                      ...           ...       ...
# Male   Millenial 9952505 youtube         176             3         0
#                  9953503 email            71             2         2
#                          facebook         56             0         0
#                          search          345             2         1
#                          youtube         117             2         0
#
#                                         CTR  conversion_rate
# gender age       uid     channel
# Female Boomer    1009283 email     0.063830         0.000000
#                          facebook  0.019608         0.000000
#                          search    0.008299         0.000000
#                          youtube   0.025890         0.000000
#                  1040848 email     0.000000         0.024096
# ...                                     ...              ...
# Male   Millenial 9952505 youtube   0.017045         0.000000
#                  9953503 email     0.028169         0.028169
#                          facebook  0.000000         0.000000
#                          search    0.005797         0.002899
#                          youtube   0.017094         0.000000
#
# [39800 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize = (8, 7))
sns.scatterplot(ax = ax, data = impressions, x = 'timestamp', y = 'clickthrough', hue = 'channel')
plt.xlabel('Impressions', size = 15)
plt.ylabel('Clicks', size = 15)
plt.title('Channel Impressions vs Clicks', size = 20)
# plt.savefig('Channelimpvsclicks.png')

# %%
fig, ax = plt.subplots(figsize = (8, 7))
sns.scatterplot(ax = ax, data = impressions, x = 'timestamp', y = 'purchase', hue = 'channel')
plt.xlabel('Impressions', size = 15)
plt.ylim((-1,17))
plt.ylabel('Conversions', size = 15)
plt.title('Channel Impressions vs Conversions', size = 20)
# plt.savefig('Channelimpvsbuy.png')

# %%
fig, ax = plt.subplots(figsize = (8, 7))
sns.scatterplot(ax = ax, data = impressions, x = 'timestamp', y = 'purchase', hue = 'gender')
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='purchase'>

# %%
fig, ax = plt.subplots(figsize = (8, 7))
sns.scatterplot(ax = ax, data = impressions, x = 'timestamp', y = 'clickthrough', hue = 'gender')
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='clickthrough'>

# %%
fig, ax = plt.subplots(figsize = (8, 7))
sns.scatterplot(ax = ax, data = impressions, x = 'timestamp', y = 'clickthrough', hue = 'age')
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='clickthrough'>

# %%
fig, ax = plt.subplots(figsize = (8, 7))
sns.scatterplot(ax = ax, data = impressions, x = 'timestamp', y = 'purchase', hue = 'age')
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='purchase'>
